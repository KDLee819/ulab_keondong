# %% [markdown]
# # HW 12 - Introduction to Pandas
# ULAB - Physics and Astronomy Division \
# Due **Sunday, February 9th, 2025 at 11:59pm** on Gradescope

# %% [markdown]
# ------
# ## 0 Academic Integrity
# Please type the following message in the cell below as a comment. Sign with your name.
#
# ------
# **I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.**
#
# ------

# %%
# Your comment here
# I certify that I did not use AI tools, such as ChatGPT, 
# to generate or write code for this assignment. 
# All work submitted is my own and reflects my understanding of the material.

# Keondong Lee

# %% [markdown]
# ------
# ## 1 Real Exoplanet Data!
# Start by importing `pandas` into your Jupyter notebook.

# %%
# Your code here
import pandas as pd

# %% [markdown]
# With a pandas dataframe, import the `exoplanet_data.csv` file. If you are curious this data is pulled directly from: https://exoplanetarchive.ipac.caltech.edu/. Due to the formating you will want to add the argument `comment='#'` to statement.

# %%
# Your code here

# Read csv file named 'exoplanet_data.csv'
df = pd.read_csv('exoplanet_data.csv')

print(df)
# Out:
#              pl_name         hostname  default_flag  sy_snum  sy_pnum  \
# 0        eps Ind A b        eps Ind A             1        3        1
# 1           AU Mic b           AU Mic             1        1        3
# 2           AU Mic c           AU Mic             1        1        3
# 3       BD-14 3065 b     BD-14 3065 A             1        3        1
# 4         DS Tuc A b         DS Tuc A             1        2        1
# 5          GJ 1252 b          GJ 1252             1        1        1
# 6        HD 101581 b        HIP 56998             1        1        2
# 7      HD 202772 A b      HD 202772 A             1        2        1
# 8        HIP 67522 b        HIP 67522             1        1        2
# 9  IRAS 04125+2902 b  IRAS 04125+2902             1        2        1
#
#    discoverymethod  disc_year                                 disc_facility  \
# 0  Radial Velocity       2019                          La Silla Observatory
# ...

# %% [markdown]
# Print the headers of your dataframe.

# %%
# Your code here

# (file read).head returns the headers of my dataframe
headers = df.head

print(headers)
# Out:
# <bound method NDFrame.head of              pl_name         hostname  default_flag  sy_snum  sy_pnum  \
# 0        eps Ind A b        eps Ind A             1        3        1
# 1           AU Mic b           AU Mic             1        1        3
# 2           AU Mic c           AU Mic             1        1        3
# 3       BD-14 3065 b     BD-14 3065 A             1        3        1
# 4         DS Tuc A b         DS Tuc A             1        2        1
# 5          GJ 1252 b          GJ 1252             1        1        1
# 6        HD 101581 b        HIP 56998             1        1        2
# 7      HD 202772 A b      HD 202772 A             1        2        1
# 8        HIP 67522 b        HIP 67522             1        1        2
# 9  IRAS 04125+2902 b  IRAS 04125+2902             1        2        1
#
#    discoverymethod  disc_year                                 disc_facility  \
# 0  Radial Velocity       2019                          La Silla Observatory
# ...

# %% [markdown]
# Print the columns of your dataframe as a list.

# %%
# Your code here

# (file read).columns returns the columns of my dataframe
columns = df.columns

print(columns)
# Out:
# Index(['pl_name', 'hostname', 'default_flag', 'sy_snum', 'sy_pnum',
#        'discoverymethod', 'disc_year', 'disc_facility', 'soltype',
#        'pl_controv_flag', 'pl_refname', 'pl_orbper', 'pl_orbpererr1',
#        'pl_orbpererr2', 'pl_orbperlim', 'pl_orbsmax', 'pl_orbsmaxerr1',
#        'pl_orbsmaxerr2', 'pl_orbsmaxlim', 'pl_rade', 'pl_radeerr1',
#        'pl_radeerr2', 'pl_radelim', 'pl_radj', 'pl_radjerr1', 'pl_radjerr2',
#        'pl_radjlim', 'pl_bmasse', 'pl_bmasseerr1', 'pl_bmasseerr2',
#        'pl_bmasselim', 'pl_bmassj', 'pl_bmassjerr1', 'pl_bmassjerr2',
#        'pl_bmassjlim', 'pl_bmassprov', 'pl_orbeccen', 'pl_orbeccenerr1',
#        'pl_orbeccenerr2', 'pl_orbeccenlim', 'pl_insol', 'pl_insolerr1',
#        'pl_insolerr2', 'pl_insollim', 'pl_eqt', 'pl_eqterr1', 'pl_eqterr2',
#        'pl_eqtlim', 'ttv_flag', 'st_refname', 'st_spectype', 'st_teff',
#        'st_tefferr1', 'st_tefferr2', 'st_tefflim', 'st_rad', 'st_raderr1',
# ...

# %% [markdown]
# Print the row of the dataframe called "pl_name", this stands for *planet name*.

# %%
# Your code here

# Extract the items under the header 'pl_name'
names = df[["pl_name"]]

print(names)
# Out:
#              pl_name
# 0        eps Ind A b
# 1           AU Mic b
# 2           AU Mic c
# 3       BD-14 3065 b
# 4         DS Tuc A b
# 5          GJ 1252 b
# 6        HD 101581 b
# 7      HD 202772 A b
# 8        HIP 67522 b
# 9  IRAS 04125+2902 b

# %% [markdown]
# Print how many planets there are.

# %%
# Your code here

# This is just the length of the extracted items
print(len(names))
# Out:
# 10

# %% [markdown]
# Make a new variable called `planet_data`. With a dataframe assign the variable the columns associated with the planet's names, planet's Earth radii, planet's Jupiter masses and planet's equilibrium temperatures. *Hint: It should look something like, `['pl_name', 'RADII', 'MASS', 'TEMPERATURE']` but with the proper column names.*

# %%
# Your code here

# My guess is the following: can extract data just like list
planet_data = df[['pl_name', 'pl_rade', 'pl_bmassj', 'pl_eqt']]

# %% [markdown]
# Print your new `planet_data` variable.

# %%
# Your code here

print(planet_data)
# Out:
#              pl_name  pl_rade  pl_bmassj  pl_eqt
# 0        eps Ind A b      NaN    6.31000   275.0
# 1           AU Mic b    3.957        NaN   600.0
# 2           AU Mic c    2.522        NaN   459.0
# 3       BD-14 3065 b   21.590   12.37000  2001.0
# 4         DS Tuc A b    5.700        NaN   850.0
# 5          GJ 1252 b    1.193    0.00415     NaN
# 6        HD 101581 b    0.956        NaN   834.0
# 7      HD 202772 A b   17.318    1.01700  2132.0
# 8        HIP 67522 b    9.987        NaN  1175.0
# 9  IRAS 04125+2902 b   10.738        NaN   854.0

# %% [markdown]
# ------
# ## 2 Plotting
# Make a scatter plot of **exoplanet Earth radius vs. equilibrium temperatures**. Include units, x/y axis labels, and a legend.

# %%
# Your code here

# Import necessary modules
import numpy as np
import matplotlib.pyplot as plt

# Make a scatter plot
plt.scatter(planet_data[['pl_rade']], planet_data[['pl_eqt']], marker = '*', color = 'darkblue', label = 'exoplanet data')

# Add plot details
plt.xlabel(r'Exoplanet Earth Radius ($\times$ 6378km)')
plt.ylabel(r'Exoplanet Equilibrium Temperature ($\degree K$)')
plt.legend()
plt.show()

# %% [markdown]
# What trend do you notice in the data? Does it have positive or negative correlation?

# %%
# Your comment here

# Generally, exoplanets with higher earth radius tends to have higher equilibrium temperature.
# This is definitely a positive correlation.

# %% [markdown]
# ------
# ## 3 A "Cool" Planet
# What planet has the **lowest** equilibrium temperature? Print the planet name and temperature with your `planet_data` variable.

# %%
# Your code here

# After observation, the planet number 0 (eps Ind A b) has the lowest equilibrium temperature of 275.0 °K
# I will use the indexing of numpy array for now
planet_array = planet_data.to_numpy()

# Use numpy array indexing [row][column]
pl_name_loweqt = planet_array[0][0]
pl_eqt_loweqt = planet_array[0][-1]

# Print out the results
print(f'The name of the planet with the lowest temperature is: {pl_name_loweqt}.')
print(f'The value of the temperature with the lowest temperature is: {pl_eqt_loweqt} °K.')
# Out:
# The name of the planet with the lowest temperature is: eps Ind A b.
# The value of the temperature with the lowest temperature is: 275.0 °K.

# %% [markdown]
# Make a new variable that only contains the information for that planet. \
# \
# *Hint: Use the `.iloc[[#]]` function. Replace # with the proper index.*

# %%
# Your code here

# Follow the instructions using the .iloc[[]] function on planet_data.
info_pl_loweqt = df.iloc[[0]]

print(info_pl_loweqt)
# Out:
#        pl_name   hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0  eps Ind A b  eps Ind A             1        3        1  Radial Velocity
#
#    disc_year         disc_facility              soltype  pl_controv_flag  ...  \
# 0       2019  La Silla Observatory  Published Confirmed                0  ...
#
#   sy_vmagerr2  sy_kmag  sy_kmagerr1  sy_kmagerr2  sy_gaiamag  sy_gaiamagerr1  \
# 0       -0.03    2.237         0.24        -0.24     4.34562        0.007374
#
#    sy_gaiamagerr2   rowupdate  pl_pubdate  releasedate
# 0       -0.007374  2024-08-07     2024-07   2024-08-07
#
# [1 rows x 92 columns]

# %% [markdown]
# Print the number of columns in the row.

# %%
# Your code here

# Need to make into a list (or array) because previous data is considered as only single object.
no_of_col = len(list(info_pl_loweqt))
print(f'There are {no_of_col} columns in this data.')
# Out:
# There are 92 columns in this data.

# %% [markdown]
# Make a new variable that contains only the columns WITHOUT `Nan` values. *Hint: You can use the function `.dropna(axis=1)`.*

# %%
# Your code here

# Follow the instructions using the .dropna(axis=1) function on planet_data.
info_pl_noNan = info_pl_loweqt.dropna(axis=1)

print(info_pl_noNan)
# Out:
#        pl_name   hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0  eps Ind A b  eps Ind A             1        3        1  Radial Velocity
#
#    disc_year         disc_facility              soltype  pl_controv_flag  ...  \
# 0       2019  La Silla Observatory  Published Confirmed                0  ...
#
#   sy_vmagerr2  sy_kmag  sy_kmagerr1  sy_kmagerr2  sy_gaiamag  sy_gaiamagerr1  \
# 0       -0.03    2.237         0.24        -0.24     4.34562        0.007374
#
#    sy_gaiamagerr2   rowupdate  pl_pubdate  releasedate
# 0       -0.007374  2024-08-07     2024-07   2024-08-07
#
# [1 rows x 74 columns]

# %% [markdown]
# Print how many columns you have now.

# %%
# Your code here

no_of_col = len(list(info_pl_noNan))
print(f'There are {no_of_col} column in this data.')
# Out:
# There are 74 column in this data.

# %% [markdown]
# Download this paper: https://www.nature.com/articles/s41586-024-07837-8. What is the title of this paper?

# %%
# Your comment here

# Title: A temperate super-Jupiter imaged with JWST in the mid-infrared

# %% [markdown]
# What are the main conclusions from the paper? Do you trust their methods? Why would they be questionable?

# %%
# Your comment here

# The main conclusion from this paper is that the exoplanet Eps Ind A b is a jupyter-like, yet very cold exoplanet.
# Their methods are appropriate in terms of they used the data from archived NEAR/VISIR images.
# Also, they made new observatons with JWST, and analyzed it by coronagraphic images.
# However, one questionable thing is that there is only one cold, jupyter-like exoplanet data.
# Since there is no other reference sources, there is no guarantee if this conclusion is consistent.

# %% [markdown]
# The planet with the **lowest effective temperature** from your `exoplanet_data.csv` file should match the planet from the paper you just downloaded. What values for the `.csv` file match the ones in the paper?

# %%
# Your comment here

# Name, equilibrium temperature, semi-major axis and its error, jupyter mass and its error,
# eccentricity, spectype, discovery year, effective temperature, metal ratio, log(g) and its error,
# host star mass and its error,

# %% [markdown]
# Which values from the `.csv` file I provided you DON'T match the ones from the paper?

# %%
## Your comment here

# st_rad: in data -> 0.68 and no errors, in paper -> 0.679 ± 0.004 Sun's radius
# sy_dist: in data -> 3.63857 ± 0.00333, in paper -> 3.6384 ± 0.0013
# pl_bmasse: in data -> 2005.49725, in paper -> after calculation 2005.42197
# Also, several magnitudes data (vmag, kmag, gaiamag) does not appear in the paper

# %% [markdown]
# In the paper, find the age of the planet. What is the age, with error, of the planet?

# %%
# Your code here

# Predicted age: 3.5 Gyr
# Upper error: + 0.8 Gyr
# Lower error: - 1.3 Gyr

# %% [markdown]
# Create a new column called `Age` with your new variable and assign it the proper value.

# %%
# Your code here

# Extract a copy of the 0th row
new_data_with_age = info_pl_loweqt.copy()

# Add the 'Age' column with the proper value
new_data_with_age["Age"] = 3.5  # Gyr

# Print the updated DataFrame
print(new_data_with_age)
# Out:
#        pl_name   hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0  eps Ind A b  eps Ind A             1        3        1  Radial Velocity
#
#    disc_year         disc_facility              soltype  pl_controv_flag  ...  \
# 0       2019  La Silla Observatory  Published Confirmed                0  ...
#
#   sy_kmag  sy_kmagerr1  sy_kmagerr2  sy_gaiamag  sy_gaiamagerr1  \
# 0   2.237         0.24        -0.24     4.34562        0.007374
#
#    sy_gaiamagerr2   rowupdate  pl_pubdate  releasedate  Age
# 0       -0.007374  2024-08-07     2024-07   2024-08-07  3.5
#
# [1 rows x 93 columns]

# %% [markdown]
# ## 4 Make a New `.csv` File

# %% [markdown]
# To a new `.csv` file, save the planet WITHOUT the Nan rows and WITH the `Age` column added.

# %%
# Your code here

# Filter out the Nan rows
data_with_age_noNan = new_data_with_age.dropna(axis=1)

# Make the new csv file using the to_csv() function
data_with_age_noNan.to_csv('New_Exoplanet_Data.csv')

# %% [markdown]
# Turn in this jupyter notebook to gradescope with your NEW `.csv` file.
